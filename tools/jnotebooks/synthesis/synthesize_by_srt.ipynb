# %%
# %matplotlib inline
from pathlib import Path

import IPython.display as ipd
from pydub import AudioSegment
from scipy.io.wavfile import write

from hparams import get_hparams_from_file
from src.model.synthesizer import InferenceConfig
from src.srt import srt_file_to_entries

# %%
checkpoint_step = '150000'
speaker = 'aurimas_nausedas'
sample_rate = 22050

checkpoint_filepath = f"/media/arnas/SSD Disk/inovoice/models/text-to-speech/vits/{speaker}/G_{checkpoint_step}.pth"
hps = get_hparams_from_file("/home/arnas/Desktop/tdi/bitbucket/vits/files/configs/mif_stressed.json")

filename = f'kur_vasara_amzina_{speaker}_{checkpoint_step}'
srt_path = Path(f"/home/arnas/Desktop/tdi/bitbucket/vits/files/audio/audiobooks/{speaker}/{checkpoint_step}/{filename}.srt")
wav_path = Path(f"/home/arnas/Desktop/tdi/bitbucket/vits/files/audio/audiobooks/{speaker}/{checkpoint_step}/{filename}.wav")
output_dir = Path(f"/home/arnas/Desktop/tdi/bitbucket/vits/files/audio/audiobooks/{speaker}/{checkpoint_step}/out")
Path(output_dir).mkdir(parents=True, exist_ok=True)

# %%
config = InferenceConfig(
    checkpoint_step=150000,
    config_name='mif_stressed',
    speaker='aurimas_nausedas',
    stressed=True,
)
# Out:
# [2022-06-22 18:04:09,405] INFO:PID-60759:MainThread:src.model.checkpoint: Loading checkpoint at /media/arnas/SSD Disk/inovoice/models/text-to-speech/vits/aurimas_nausedas/G_150000.pth
# [INFO] Loading checkpoint at /media/arnas/SSD Disk/inovoice/models/text-to-speech/vits/aurimas_nausedas/G_150000.pth
# [2022-06-22 18:04:09,687] INFO:PID-60759:MainThread:src.model.checkpoint: Loaded checkpoint '/media/arnas/SSD Disk/inovoice/models/text-to-speech/vits/aurimas_nausedas/G_150000.pth' (iteration 981)
# [INFO] Loaded checkpoint '/media/arnas/SSD Disk/inovoice/models/text-to-speech/vits/aurimas_nausedas/G_150000.pth' (iteration 981)

# %%
wav = AudioSegment.from_wav(wav_path)

# %%
srt_entries = srt_file_to_entries(srt_path, wav)

# %%
# TODO: add functionality to select only entries with `*`
for entry in srt_entries:
    while True:
        ipd.display(ipd.Audio(entry.audio.get_array_of_samples(), rate=sample_rate, normalize=True))
        option = int(input("[1] Next entry\n[2] Resynthesize\n"))
        if option == 1:
            pass
        elif option == 2:
            pass
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_60759/2179028139.py in <module>
#       2     while True:
#       3         ipd.display(ipd.Audio(entry.audio.get_array_of_samples(), rate=sample_rate, normalize=True))
# ----> 4         option = int(input("[1] Next entry\n[2] Resynthesize\n"))
#       5         if option == 1:
#       6             pass
#
# ValueError: invalid literal for int() with base 10: ''

# %%
write(f"{output_dir}/{output_filename}.wav", sample_rate, audiobook)

# %%
p = Path(f"/home/arnas/Downloads/test_utterance.wav")
wav = AudioSegment.from_wav(p)

# %%
sl = wav[200: 1000]

# %%
new = wav + sl

# %%
import numpy as np
from io import BytesIO

nparr = np.array(sl.get_array_of_samples())
b = BytesIO()
write(b, rate=22050, data=nparr)
aseg = AudioSegment.from_wav(b)

# %%
new1 = new[0:300] + aseg + new[1100:1200] + aseg

# %%
new1.export("/home/arnas/Downloads/test_utterance1.wav", format='wav')
# Out:
# <_io.BufferedRandom name='/home/arnas/Downloads/test_utterance1.wav'>
